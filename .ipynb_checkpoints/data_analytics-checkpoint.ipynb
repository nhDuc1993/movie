# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
pd.set_option('display.max_columns', None)

filepath = r'C:\Users\ADMIN\Desktop\python\project'
df = pd.read_csv(filepath + r'\clean_data\fact_movie.csv', encoding='UTF-8', engine='python')
df
# Out:
#           id     budget                                      homepage  \
# 0      19995  237000000                   http://www.avatarmovie.com/
# 1        285  300000000  http://disney.go.com/disneypictures/pirates/
# 2     206647  245000000   http://www.sonypictures.com/movies/spectre/
# 3      49026  250000000            http://www.thedarkknightrises.com/
# 4      49529  260000000          http://movies.disney.com/john-carter
# ...      ...        ...                                           ...
# 4362     692      12000                                           NaN
# 4363   39851      10000                                           NaN
# 4364   13898   18000000                                           NaN
# 4365   36095      20000                                           NaN
# 4366    9367     220000                                           NaN
#
#                                                keywords  \
# 0     culture clash future space war space colony so...
# 1     ocean drug abuse exotic island east india trad...
# 2            spy based on novel secret agent sequel mi6
# 3     dc comics crime fighter terrorist secret ident...
# 4     based on novel mars medallion space travel pri...
# ...                                                 ...
# 4362    gay trailer park pop culture drug dealer heroin
# 4363     addiction recovering drug addict estranged son
# 4364                                                NaN
# 4365  japan prostitute hotel based on novel hallucin...
# 4366  united states–mexico barrier legs arms paper k...
#
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4362                            Pink Flamingos
# 4363                                     Clean
# 4364                                     دایره
# 4365                                       キュア
# 4366                               El Mariachi
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# ...                                                 ...         ...
# 4362  Notorious Baltimore criminal and underground f...    4.553644
# 4363  After losing her husband to a heroin overdose,...    1.464566
# 4364  Various women struggle to function in the oppr...    1.193779
# 4365  A wave of gruesome murders is sweeping Tokyo. ...    0.212443
# 4366  El Mariachi just wants to play his guitar and ...   14.269792
#
#      release_date     revenue  runtime  \
# 0      2009-12-10  2787965087    162.0
# 1      2007-05-19   961000000    169.0
# 2      2015-10-26   880674609    148.0
# 3      2012-07-16  1084939099    165.0
# 4      2012-03-07   284139100    132.0
# ...           ...         ...      ...
# 4362   1972-03-12     6000000     93.0
# 4363   2004-09-01      138711    111.0
# 4364   2000-09-08    40651864     90.0
# 4365   1997-11-06       99000    111.0
# 4366   1992-09-04     2040920     81.0
#
#                                                 tagline  \
# 0                           Enter the World of Pandora.
# 1        At the end of the world, the adventure begins.
# 2                                 A Plan No One Escapes
# 3                                       The Legend Ends
# 4                  Lost in our world, found in another.
# ...                                                 ...
# 4362                         An exercise in poor taste.
# 4363          When you don't have a choice, you change.
# 4364                                                NaN
# 4365                           Madness. Terror. Murder.
# 4366  He didn't come looking for trouble, but troubl...
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                  John Carter           6.1        2124
# ...                                        ...           ...         ...
# 4362                            Pink Flamingos           6.2         110
# 4363                                     Clean           6.7          17
# 4364                                The Circle           6.6          17
# 4365                                      Cure           7.4          63
# 4366                               El Mariachi           6.6         238
#
#                                                    cast           director  \
# 0     Sam Worthington Zoe Saldana Sigourney Weaver S...      James Cameron
# 1     Johnny Depp Orlando Bloom Keira Knightley Stel...     Gore Verbinski
# 2     Daniel Craig Christoph Waltz Léa Seydoux Ralph...         Sam Mendes
# 3     Christian Bale Michael Caine Gary Oldman Anne ...  Christopher Nolan
# 4     Taylor Kitsch Lynn Collins Samantha Morton Wil...     Andrew Stanton
# ...                                                 ...                ...
# 4362  Divine David Lochary Mary Vivian Pearce Mink S...        John Waters
# 4363  Maggie Cheung Nick Nolte Béatrice Dalle Jeanne...    Olivier Assayas
# 4364  Nargess Mamizadeh Maryiam Palvin Almani Mojgan...       Jafar Panahi
# 4365  Koji Yakusho Masato Hagiwara Tsuyoshi Ujiki An...   Kiyoshi Kurosawa
# 4366  Carlos Gallardo Jaime de Hoyos Peter Marquardt...   Robert Rodriguez
#
#       profitability  day  month  year  inflated_budget  inflated_revenue  \
# 0           1176.36   10     12  2009        294566979        3465158039
# 1            320.33   19      5  2007        387784378        1242202625
# 2            359.46   26     10  2015        275830753         991498536
# 3            433.98   16      7  2012        289960043        1258355953
# 4            109.28    7      3  2012        301558445         329555943
# ...             ...  ...    ...   ...              ...               ...
# 4362       50000.00   12      3  1972            76755          38377973
# 4363        1387.11    1      9  2004            14124            195925
# 4364         225.84    8      9  2000         28062607          63377628
# 4365         495.00    6     11  1997            33413            165397
# 4366         927.69    4      9  1992           421953           3914426
#
#       weighted_rating
# 0               7.198
# 1               6.898
# 2               6.306
# 3               7.595
# 4               6.116
# ...               ...
# 4362            6.386
# 4363            6.749
# 4364            6.725
# 4365            7.107
# 4366            6.630
#
# [4367 rows x 23 columns]

# %%
# Get budget/revenue columns

budget = df['budget']
revenue = df['revenue']

# %%
# Visualize

fig, axes = plt.subplots(1, 1, figsize = (12, 12))
plt.scatter(budget, revenue, s=10)
plt.xlabel('budget')
plt.ylabel('revenue')
# Out:
# Text(0, 0.5, 'revenue')

# %%
# Linear Regression

model = LinearRegression(fit_intercept=True)
x = budget
y = revenue
X = x[:, np.newaxis]
model.fit(X, y)
yfit = model.predict(X)
# Out:
# <ipython-input-165-9b31605f731d>:6: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   X = x[:, np.newaxis]

# %%
model.coef_
# Out:
# array([2.94826797])

# %%
model.intercept_
# Out:
# -5403896.046397179

# %%
fig, axes = plt.subplots(1, 1, figsize = (12, 12))
plt.scatter(budget, revenue, s=10)
plt.plot(x, yfit, c ='r')
plt.xlabel('budget')
plt.ylabel('revenue')
# Out:
# Text(0, 0.5, 'revenue')

# %%
pd.set_option('display.max_row', 100)

filepath = r'C:\Users\ADMIN\Desktop\python\project'
df_org = pd.read_csv(filepath + '\data\movie_dataset.csv', encoding='UTF-8', engine='python', index_col='index')

df_test  = df[['id', 'title', 'inflated_budget','profitability', 'runtime', 'weighted_rating']]

df_test = pd.merge(df_test, df_org[['id', 'genres']], how='left', left_on='id', right_on='id')
df_test = df_test.iloc[df_test['genres'].dropna().index, :]
df_test['genres'] = df_test['genres'].apply(lambda x: x.split()[0] if x.split()[0] != 'Science' else 'Science Fiction' )
df_test = df_test.drop(['id', 'title'], axis=1)
df_test.dropna(inplace=True)
df_test
# Out:
#       inflated_budget  profitability  runtime  weighted_rating     genres
# 0           294566979        1176.36    162.0            7.198     Action
# 1           387784378         320.33    169.0            6.898  Adventure
# 2           275830753         359.46    148.0            6.306     Action
# 3           289960043         433.98    165.0            7.595     Action
# 4           301558445         109.28    132.0            6.116     Action
# ...               ...            ...      ...              ...        ...
# 4362            76755       50000.00     93.0            6.386     Horror
# 4363            14124        1387.11    111.0            6.749      Drama
# 4364         28062607         225.84     90.0            6.725      Drama
# 4365            33413         495.00    111.0            7.107      Crime
# 4366           421953         927.69     81.0            6.630     Action
#
# [4352 rows x 5 columns]

# %%
sns.pairplot(df_test, hue='genres')
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
# GaussianNB

X = df_test.drop(['genres'], axis=1)
y = df_test['genres']

Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, random_state=1)

model = GaussianNB()

model.fit(Xtrain, ytrain)

y_model = model.predict(Xtest)

accuracy_score(ytest, y_model)
# Out:
# 0.2693014705882353

# %%
# Kmeans

X = df_test.drop(['genres'], axis=1)
y = df_test['genres']

scaler = StandardScaler()
X = scaler.fit_transform(X)
model = PCA(n_components = 2)
model.fit(X)
X_2D = model.transform(X)

kmeans = KMeans(n_clusters = 20)
kmeans.fit(X_2D)
y_kmeans = kmeans.predict(X_2D)

# %%
#############################
#############################
#############################

filepath = r'C:\Users\ADMIN\Desktop\python\project'
df_genres = pd.read_csv(filepath + '\clean_data\dim_genres.csv', encoding='UTF-8', engine='python')
df_genres = df_genres.groupby('movie_id').agg({'genres': lambda x: ','.join(x)}).reset_index()

# %%
df_test  = df[['id', 'inflated_budget','profitability', 'runtime', 'weighted_rating']]

df_test = pd.merge(df_test, df_genres, how='left', left_on='id', right_on='movie_id')
df_test = df_test.iloc[df_test['genres'].dropna().index, :]
df_test = df_test.drop(['movie_id'], axis=1)
df_test.dropna(inplace=True)
df_test
# Out:
#           id  inflated_budget  profitability  runtime  weighted_rating  \
# 0      19995        294566979        1176.36    162.0            7.198
# 1        285        387784378         320.33    169.0            6.898
# 2     206647        275830753         359.46    148.0            6.306
# 3      49026        289960043         433.98    165.0            7.595
# 4      49529        301558445         109.28    132.0            6.116
# ...      ...              ...            ...      ...              ...
# 4362     692            76755       50000.00     93.0            6.386
# 4363   39851            14124        1387.11    111.0            6.749
# 4364   13898         28062607         225.84     90.0            6.725
# 4365   36095            33413         495.00    111.0            7.107
# 4366    9367           421953         927.69     81.0            6.630
#
#                                         genres
# 0     Action,Adventure,Fantasy,Science Fiction
# 1                     Adventure,Fantasy,Action
# 2                       Action,Adventure,Crime
# 3                  Action,Crime,Drama,Thriller
# 4             Action,Adventure,Science Fiction
# ...                                        ...
# 4362                       Horror,Comedy,Crime
# 4363                                     Drama
# 4364                             Drama,Foreign
# 4365             Crime,Horror,Mystery,Thriller
# 4366                     Action,Crime,Thriller
#
# [4352 rows x 6 columns]

# %%
# Profit?
df_test['profitability'] = df_test['profitability'].apply(lambda x: 1 if x > 100 else 0)

# %%
# Inflated_budget

df_test = df_test[df_test['inflated_budget'] != df_test['inflated_budget'].max()]
g = sns.FacetGrid(df_test, col='profitability', height=10)
g.map(plt.hist, 'inflated_budget', bins=20)

# %%
# Create bin

df_test['inflated_budget_bin'] = pd.cut(df_test['inflated_budget'], 5)
df_test[['inflated_budget_bin', 'profitability']].groupby(['inflated_budget_bin'], as_index=False).mean()
# Out:
# <ipython-input-177-a7f2e74ce224>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['inflated_budget_bin'] = pd.cut(df_test['inflated_budget'], 5)
#           inflated_budget_bin  profitability
# 0   (-435415.927, 89922109.4]       0.647530
# 1   (89922109.4, 179830094.8]       0.765653
# 2  (179830094.8, 269738080.2]       0.929577
# 3  (269738080.2, 359646065.6]       0.920000
# 4  (359646065.6, 449554051.0]       1.000000

# %%
# Apply bins

df_test.loc[ df_test['inflated_budget'] <= 89922109.4, 'inflated_budget'] = 0
df_test.loc[(df_test['inflated_budget'] > 89922109.4) & (df_test['inflated_budget'] <= 179830094.8), 'inflated_budget'] = 1
df_test.loc[(df_test['inflated_budget'] > 179830094.8) & (df_test['inflated_budget'] <= 269738080.2), 'inflated_budget'] = 2
df_test.loc[(df_test['inflated_budget'] > 269738080.2) & (df_test['inflated_budget'] <= 359646065.6), 'inflated_budget'] = 3
df_test.loc[ df_test['inflated_budget'] > 359646065.6, 'inflated_budget'] = 4
df_test.drop('inflated_budget_bin', axis=1, inplace=True)
df_test
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\ADMIN\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\ADMIN\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\ADMIN\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\ADMIN\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\ADMIN\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#           id  inflated_budget  profitability  runtime  weighted_rating  \
# 0      19995                3              1    162.0            7.198
# 1        285                4              1    169.0            6.898
# 2     206647                3              1    148.0            6.306
# 3      49026                3              1    165.0            7.595
# 4      49529                3              1    132.0            6.116
# ...      ...              ...            ...      ...              ...
# 4362     692                0              1     93.0            6.386
# 4363   39851                0              1    111.0            6.749
# 4364   13898                0              1     90.0            6.725
# 4365   36095                0              1    111.0            7.107
# 4366    9367                0              1     81.0            6.630
#
#                                         genres
# 0     Action,Adventure,Fantasy,Science Fiction
# 1                     Adventure,Fantasy,Action
# 2                       Action,Adventure,Crime
# 3                  Action,Crime,Drama,Thriller
# 4             Action,Adventure,Science Fiction
# ...                                        ...
# 4362                       Horror,Comedy,Crime
# 4363                                     Drama
# 4364                             Drama,Foreign
# 4365             Crime,Horror,Mystery,Thriller
# 4366                     Action,Crime,Thriller
#
# [4351 rows x 6 columns]

# %%
# Runtime
df_test = df_test[df_test['runtime'] != 0]

g = sns.FacetGrid(df_test, col='profitability', height=10)
g.map(plt.hist, 'runtime', bins=4)

# %%
df_test['runtime_bin'] = pd.cut(df_test['runtime'], 4)
df_test[['runtime_bin', 'profitability']].groupby(['runtime_bin'], as_index=False).mean()
# Out:
#         runtime_bin  profitability
# 0  (40.703, 115.25]       0.647251
# 1   (115.25, 189.5]       0.739921
# 2   (189.5, 263.75]       0.607143
# 3   (263.75, 338.0]       0.000000

# %%
df_test.loc[ df_test['runtime'] <= 115.25, 'runtime'] = 0
df_test.loc[(df_test['runtime'] > 115.25) & (df_test['runtime'] <= 189.5), 'runtime'] = 1
df_test.loc[(df_test['runtime'] > 189.5) & (df_test['runtime'] <= 263.75), 'runtime'] = 2
df_test.loc[ df_test['runtime'] > 263.75, 'runtime'] = 3
df_test.drop('runtime_bin', axis=1, inplace=True)
df_test['runtime'] = df_test['runtime'].astype(int)
df_test
# Out:
#           id  inflated_budget  profitability  runtime  weighted_rating  \
# 0      19995                3              1        1            7.198
# 1        285                4              1        1            6.898
# 2     206647                3              1        1            6.306
# 3      49026                3              1        1            7.595
# 4      49529                3              1        1            6.116
# ...      ...              ...            ...      ...              ...
# 4362     692                0              1        0            6.386
# 4363   39851                0              1        0            6.749
# 4364   13898                0              1        0            6.725
# 4365   36095                0              1        0            7.107
# 4366    9367                0              1        0            6.630
#
#                                         genres
# 0     Action,Adventure,Fantasy,Science Fiction
# 1                     Adventure,Fantasy,Action
# 2                       Action,Adventure,Crime
# 3                  Action,Crime,Drama,Thriller
# 4             Action,Adventure,Science Fiction
# ...                                        ...
# 4362                       Horror,Comedy,Crime
# 4363                                     Drama
# 4364                             Drama,Foreign
# 4365             Crime,Horror,Mystery,Thriller
# 4366                     Action,Crime,Thriller
#
# [4351 rows x 6 columns]

# %%
# weighted rating
g = sns.FacetGrid(df_test, col='profitability', height=10)
g.map(plt.hist, 'weighted_rating', bins=4)

# %%
df_test['weighted_rating_bin'] = pd.cut(df_test['weighted_rating'], 4)
df_test[['weighted_rating_bin', 'profitability']].groupby(['weighted_rating_bin'], as_index=False).mean()
# Out:
#   weighted_rating_bin  profitability
# 0        (3.299, 4.6]       0.576923
# 1        (4.6, 5.896]       0.676923
# 2      (5.896, 7.193]       0.636864
# 3      (7.193, 8.489]       0.921397

# %%
df_test.loc[ df_test['weighted_rating'] <= 4.6, 'weighted_rating'] = 0
df_test.loc[(df_test['weighted_rating'] > 4.6) & (df_test['weighted_rating'] <= 5.896), 'weighted_rating'] = 1
df_test.loc[(df_test['weighted_rating'] > 5.896) & (df_test['weighted_rating'] <= 7.193), 'weighted_rating'] = 2
df_test.loc[ df_test['weighted_rating'] > 7.193, 'weighted_rating'] = 3
df_test.drop('weighted_rating_bin', axis=1, inplace=True)
df_test['weighted_rating'] = df_test['weighted_rating'].astype(int)
df_test
# Out:
#           id  inflated_budget  profitability  runtime  weighted_rating  \
# 0      19995                3              1        1                3
# 1        285                4              1        1                2
# 2     206647                3              1        1                2
# 3      49026                3              1        1                3
# 4      49529                3              1        1                2
# ...      ...              ...            ...      ...              ...
# 4362     692                0              1        0                2
# 4363   39851                0              1        0                2
# 4364   13898                0              1        0                2
# 4365   36095                0              1        0                2
# 4366    9367                0              1        0                2
#
#                                         genres
# 0     Action,Adventure,Fantasy,Science Fiction
# 1                     Adventure,Fantasy,Action
# 2                       Action,Adventure,Crime
# 3                  Action,Crime,Drama,Thriller
# 4             Action,Adventure,Science Fiction
# ...                                        ...
# 4362                       Horror,Comedy,Crime
# 4363                                     Drama
# 4364                             Drama,Foreign
# 4365             Crime,Horror,Mystery,Thriller
# 4366                     Action,Crime,Thriller
#
# [4351 rows x 6 columns]

# %%
# Genres

filepath = r'C:\Users\ADMIN\Desktop\python\project'
df_genres = pd.read_csv(filepath + '\clean_data\dim_genres.csv', encoding='UTF-8', engine='python')
pd.merge(df_test[['id','profitability']], df_genres, how='left', left_on='id', right_on='movie_id')
df_genres = pd.merge(df_test[['id','profitability']], df_genres, how='left', left_on='id', right_on='movie_id')
df_genres = df_genres.groupby('genres').mean().profitability.sort_values(ascending=False)
df_genres

# %%
def genre_cal(genre):
    s = 0
    for i in genre.split(","):
        s += df_genres[i]
        
    return s/len(genre.split(","))
df_test['genres'] = df_test['genres'].apply(lambda x: genre_cal(x))

# %%
# weighted rating
g = sns.FacetGrid(df_test, col='profitability', height=10)
g.map(plt.hist, 'genres', bins=4)

# %%
df_test['genres_bin'] = pd.cut(df_test['genres'], 4)
df_test[['genres_bin', 'profitability']].groupby(['genres_bin'], as_index=False).mean()
# Out:
#        genres_bin  profitability
# 0  (0.483, 0.554]       0.285714
# 1  (0.554, 0.625]       0.596737
# 2  (0.625, 0.696]       0.648327
# 3  (0.696, 0.767]       0.761084

# %%
df_test.loc[ df_test['genres'] <= 0.554, 'genres'] = 0
df_test.loc[(df_test['genres'] > 0.554) & (df_test['genres'] <= 0.625), 'genres'] = 1
df_test.loc[(df_test['genres'] > 0.625) & (df_test['genres'] <= 0.696), 'genres'] = 2
df_test.loc[ df_test['genres'] > 0.696, 'genres'] = 3
df_test.drop('genres_bin', axis=1, inplace=True)
df_test['genres'] = df_test['genres'].astype(int)
df_test
# Out:
#           id  inflated_budget  profitability  runtime  weighted_rating  genres
# 0      19995                3              1        1                3       3
# 1        285                4              1        1                2       3
# 2     206647                3              1        1                2       3
# 3      49026                3              1        1                3       3
# 4      49529                3              1        1                2       3
# ...      ...              ...            ...      ...              ...     ...
# 4362     692                0              1        0                2       3
# 4363   39851                0              1        0                2       3
# 4364   13898                0              1        0                2       0
# 4365   36095                0              1        0                2       3
# 4366    9367                0              1        0                2       3
#
# [4351 rows x 6 columns]

# %%
X = df_test.drop(['id', 'profitability'], axis=1)
y = df_test['profitability']

Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, random_state=1)

# %%
# Logistic Regression

logreg = LogisticRegression()
logreg.fit(Xtrain, ytrain)
Y_pred = logreg.predict(Xtest)
acc_log = logreg.score(Xtrain, ytrain)
acc_score = accuracy_score(ytest, Y_pred)
print(acc_log)
print(acc_score)
# Out:
# 0.6748391051179896
# 0.671875

# %%
coeff_df = pd.DataFrame(df_test.columns.delete([0,2]))
coeff_df.columns = ['Feature']
coeff_df["Correlation"] = pd.Series(logreg.coef_[0])

coeff_df.sort_values(by='Correlation', ascending=False)
# Out:
#            Feature  Correlation
# 3           genres     0.770436
# 0  inflated_budget     0.668741
# 2  weighted_rating     0.405640
# 1          runtime     0.174760

# %%
# Support Vector Machines

svc = SVC()
svc.fit(Xtrain, ytrain)
Y_pred = svc.predict(Xtest)
acc_svc = round(svc.score(Xtrain, ytrain) * 100, 2)
acc_svc
# Out:
# 67.55
